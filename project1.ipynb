# %%
import requests
import time
import json
from typing import List, Dict
from datetime import datetime

class GitHubScraper:
    def __init__(self, token: str):
        """
        Initialize the scraper with GitHub API token
        
        Args:
            token (str): GitHub Personal Access Token
        """
        self.headers = {
            'Authorization': f'token {token}',
            'Accept': 'application/vnd.github.v3+json'
        }
        self.base_url = 'https://api.github.com'
        
    def search_users(self, min_followers: int = 100, location: str = 'Chicago') -> List[Dict]:
        """
        Search for GitHub users in specified location with minimum followers
        
        Args:
            min_followers (int): Minimum number of followers
            location (str): Location to search for
            
        Returns:
            List[Dict]: List of user data dictionaries
        """
        users = []
        page = 1
        
        while True:
            search_url = f'{self.base_url}/search/users'
            params = {
                'q': f'location:{location} followers:>={min_followers}',
                'per_page': 100,
                'page': page
            }
            
            response = requests.get(search_url, headers=self.headers, params=params)
            
            if response.status_code != 200:
                print(f"Error searching users: {response.status_code}")
                print(response.json())
                break
                
            data = response.json()
            if not data['items']:
                break
                
            # Get detailed information for each user
            for user in data['items']:
                user_detail = self.get_user_details(user['login'])
                if user_detail:
                    users.append(user_detail)
                    
                # Respect API rate limits
                time.sleep(1)
                
            page += 1
            
        return users
    
    def get_user_details(self, username: str) -> Dict:
        """
        Get detailed information for a specific user
        
        Args:
            username (str): GitHub username
            
        Returns:
            Dict: User details dictionary
        """
        user_url = f'{self.base_url}/users/{username}'
        response = requests.get(user_url, headers=self.headers)
        
        if response.status_code != 200:
            print(f"Error fetching user details for {username}: {response.status_code}")
            return None
            
        return response.json()
    
    def get_user_repositories(self, username: str) -> List[Dict]:
        """
        Get repositories for a specific user
        
        Args:
            username (str): GitHub username
            
        Returns:
            List[Dict]: List of repository dictionaries
        """
        repos = []
        page = 1
        
        while True:
            repos_url = f'{self.base_url}/users/{username}/repos'
            params = {
                'per_page': 100,
                'page': page
            }
            
            response = requests.get(repos_url, headers=self.headers, params=params)
            
            if response.status_code != 200:
                print(f"Error fetching repositories for {username}: {response.status_code}")
                break
                
            data = response.json()
            if not data:
                break
                
            repos.extend(data)
            page += 1
            
        return repos

def main():
    # Replace with your GitHub Personal Access Token
    token = 'key'
    scraper = GitHubScraper(token)
    
    # Search for users in Chicago with >100 followers
    users = scraper.search_users(min_followers=100, location='Chicago')
    
    # Create output structure
    output = []
    for user in users:
        user_data = user.copy()
        # Add repositories to user data
        user_data['repositories'] = scraper.get_user_repositories(user['login'])
        output.append(user_data)
        
        # Respect API rate limits
        time.sleep(1)
    
    # Save results to file
    timestamp = datetime.now().strftime('%Y%m%d_%H%M%S')
    filename = f'github_chicago_users_{timestamp}.json'
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(output, f, indent=2)
        
    print(f"Found {len(users)} users. Data saved to {filename}")

if __name__ == "__main__":
    main()
# Out:
# Found 380 users. Data saved to github_chicago_users_20241030_120752.json

# %%
import pandas as pd
import json

def load_github_json(filename: str) -> pd.DataFrame:
    """
    Load GitHub users JSON file and convert it to a DataFrame with specified columns
    
    Args:
        filename (str): Path to the JSON file
        
    Returns:
        pd.DataFrame: DataFrame containing user information
    """
    # Define the columns we want to extract
    columns = [
        'login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url', 
        'html_url', 'followers_url', 'following_url', 'gists_url', 
        'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url',
        'events_url', 'received_events_url', 'type', 'user_view_type', 
        'site_admin', 'name', 'company', 'blog', 'location', 'email',
        'hireable', 'bio', 'twitter_username', 'public_repos', 'public_gists',
        'followers', 'following', 'created_at', 'updated_at'
    ]
    
    # Read JSON file
    try:
        with open(filename, 'r', encoding='utf-8') as f:
            data = json.load(f)
    except FileNotFoundError:
        print(f"Error: File '{filename}' not found")
        return None
    except json.JSONDecodeError:
        print(f"Error: File '{filename}' is not valid JSON")
        return None
    
    # Convert to DataFrame
    df = pd.DataFrame(data)
    
    # Select only the specified columns
    # If a column doesn't exist, it will be filled with NaN
    df = df.reindex(columns=columns)
    
    # Convert timestamp strings to datetime objects
    timestamp_columns = ['created_at', 'updated_at']
    for col in timestamp_columns:
        if col in df.columns:
            df[col] = pd.to_datetime(df[col])
    
    # Print basic information about the DataFrame
    print(f"\nDataFrame Info:")
    print(f"Number of users: {len(df)}")
    print(f"Number of columns: {len(df.columns)}")
    print("\nMissing columns:", set(columns) - set(df.columns))
    print("\nFirst few rows:")
    print(df.head())
    
    return df

def main():
    # File path
    filename = '/home/neil/Desktop/github_chicago_users_20241030_120752.json'
    
    # Load and convert the data
    df = load_github_json(filename)
    
    if df is not None:
        # Save to CSV for easy viewing
        csv_filename = filename.replace('.json', '.csv')
        df.to_csv(csv_filename, index=False)
        print(f"\nData saved to {csv_filename}")
        
        # Basic data analysis
        print("\nBasic Statistics:")
        print(f"Total number of users: {len(df)}")
        print(f"Average followers: {df['followers'].mean():.2f}")
        print(f"Average public repos: {df['public_repos'].mean():.2f}")
        print("\nTop 5 users by followers:")
        print(df.nlargest(5, 'followers')[['login', 'followers', 'public_repos']])

if __name__ == "__main__":
    main()
# Out:
# DataFrame Info:
# Number of users: 380
# Number of columns: 33
#
# Missing columns: set()
#
# First few rows:
#          login       id               node_id  \
# 0     cassidoo  1454517  MDQ6VXNlcjE0NTQ1MTc=
# 1     felangel  8855632  MDQ6VXNlcjg4NTU2MzI=
# 2       dabeaz   350836  MDQ6VXNlcjM1MDgzNg==
# 3  sstephenson     2603      MDQ6VXNlcjI2MDM=
# 4  mattgodbolt   633973  MDQ6VXNlcjYzMzk3Mw==
#
#                                           avatar_url gravatar_id  \
# 0  https://avatars.githubusercontent.com/u/145451...
# 1  https://avatars.githubusercontent.com/u/885563...
# 2  https://avatars.githubusercontent.com/u/350836...
# 3   https://avatars.githubusercontent.com/u/2603?v=4
# 4  https://avatars.githubusercontent.com/u/633973...
#
#                                         url                        html_url  \
# 0     https://api.github.com/users/cassidoo     https://github.com/cassidoo
# 1     https://api.github.com/users/felangel     https://github.com/felangel
# 2       https://api.github.com/users/dabeaz       https://github.com/dabeaz
# 3  https://api.github.com/users/sstephenson  https://github.com/sstephenson
# 4  https://api.github.com/users/mattgodbolt  https://github.com/mattgodbolt
#
#                                        followers_url  \
# 0    https://api.github.com/users/cassidoo/followers
# 1    https://api.github.com/users/felangel/followers
# 2      https://api.github.com/users/dabeaz/followers
# 3  https://api.github.com/users/sstephenson/follo...
# 4  https://api.github.com/users/mattgodbolt/follo...
#
#                                        following_url  \
# 0  https://api.github.com/users/cassidoo/followin...
# 1  https://api.github.com/users/felangel/followin...
# 2  https://api.github.com/users/dabeaz/following{...
# 3  https://api.github.com/users/sstephenson/follo...
# 4  https://api.github.com/users/mattgodbolt/follo...
#
#                                            gists_url  ...  \
# 0  https://api.github.com/users/cassidoo/gists{/g...  ...
# 1  https://api.github.com/users/felangel/gists{/g...  ...
# 2  https://api.github.com/users/dabeaz/gists{/gis...  ...
# 3  https://api.github.com/users/sstephenson/gists...  ...
# 4  https://api.github.com/users/mattgodbolt/gists...  ...
#
#                   email hireable  \
# 0                  None     None
# 1  felangelov@gmail.com     None
# 2       dave@dabeaz.com     None
# 3          sam@sls.name     None
# 4      matt@godbolt.org     None
#
#                                                  bio twitter_username  \
# 0            Making memes and dreams... and software         cassidoo
# 1  software engineer by day, software engineer by...       felangelov
# 2  Author of the Python Essential Reference (Addi...             None
# 3                                               None             None
# 4  Compiler Explorer and jsbeeb creator, ex-Googl...             None
#
#   public_repos public_gists followers following                created_at  \
# 0          165           47     13380       102 2012-02-20 16:36:23+00:00
# 1          125          293      8672        67 2014-09-22 02:35:58+00:00
# 2           34           10      5180         0 2010-08-01 15:22:48+00:00
# 3           24           58      3761         0 2008-03-08 22:17:24+00:00
# 4           84           17      3397        97 2011-02-23 13:46:48+00:00
#
#                  updated_at
# 0 2024-10-24 18:59:19+00:00
# 1 2024-10-28 17:01:55+00:00
# 2 2024-01-08 14:46:16+00:00
# 3 2024-09-28 16:33:20+00:00
# 4 2024-10-24 02:11:12+00:00
#
# [5 rows x 33 columns]
#
# Data saved to /home/neil/Desktop/github_chicago_users_20241030_120752.csv
#
# Basic Statistics:
# Total number of users: 380
# Average followers: 387.40
# Average public repos: 96.46
#
# Top 5 users by followers:
#          login  followers  public_repos
# 0     cassidoo      13380           165
# 1     felangel       8672           125
# 2       dabeaz       5180            34
# 3  sstephenson       3761            24
# 4  mattgodbolt       3397            84

# %%
filepath='/home/neil/Desktop/github_chicago_users_20241030_120752.csv'
df = pd.read_csv(filepath)

# %%
df
# Out:
#            login       id               node_id  \
# 0       cassidoo  1454517  MDQ6VXNlcjE0NTQ1MTc=
# 1       felangel  8855632  MDQ6VXNlcjg4NTU2MzI=
# 2         dabeaz   350836  MDQ6VXNlcjM1MDgzNg==
# 3    sstephenson     2603      MDQ6VXNlcjI2MDM=
# 4    mattgodbolt   633973  MDQ6VXNlcjYzMzk3Mw==
# ..           ...      ...                   ...
# 375      cwarden   387035  MDQ6VXNlcjM4NzAzNQ==
# 376      nadrane  1634953  MDQ6VXNlcjE2MzQ5NTM=
# 377     rogeruiz   706004  MDQ6VXNlcjcwNjAwNA==
# 378    scottferg    74309      MDQ6VXNlcjc0MzA5
# 379       jebeck  1588547  MDQ6VXNlcjE1ODg1NDc=
#
#                                             avatar_url  gravatar_id  \
# 0    https://avatars.githubusercontent.com/u/145451...          NaN
# 1    https://avatars.githubusercontent.com/u/885563...          NaN
# 2    https://avatars.githubusercontent.com/u/350836...          NaN
# 3     https://avatars.githubusercontent.com/u/2603?v=4          NaN
# 4    https://avatars.githubusercontent.com/u/633973...          NaN
# ..                                                 ...          ...
# 375  https://avatars.githubusercontent.com/u/387035...          NaN
# 376  https://avatars.githubusercontent.com/u/163495...          NaN
# 377  https://avatars.githubusercontent.com/u/706004...          NaN
# 378  https://avatars.githubusercontent.com/u/74309?v=4          NaN
# 379  https://avatars.githubusercontent.com/u/158854...          NaN
#
#                                           url                        html_url  \
# 0       https://api.github.com/users/cassidoo     https://github.com/cassidoo
# 1       https://api.github.com/users/felangel     https://github.com/felangel
# 2         https://api.github.com/users/dabeaz       https://github.com/dabeaz
# 3    https://api.github.com/users/sstephenson  https://github.com/sstephenson
# 4    https://api.github.com/users/mattgodbolt  https://github.com/mattgodbolt
# ..                                        ...                             ...
# 375      https://api.github.com/users/cwarden      https://github.com/cwarden
# 376      https://api.github.com/users/nadrane      https://github.com/nadrane
# 377     https://api.github.com/users/rogeruiz     https://github.com/rogeruiz
# 378    https://api.github.com/users/scottferg    https://github.com/scottferg
# 379       https://api.github.com/users/jebeck       https://github.com/jebeck
#
#                                          followers_url  \
# 0      https://api.github.com/users/cassidoo/followers
# 1      https://api.github.com/users/felangel/followers
# 2        https://api.github.com/users/dabeaz/followers
# 3    https://api.github.com/users/sstephenson/follo...
# 4    https://api.github.com/users/mattgodbolt/follo...
# ..                                                 ...
# 375     https://api.github.com/users/cwarden/followers
# 376     https://api.github.com/users/nadrane/followers
# 377    https://api.github.com/users/rogeruiz/followers
# 378   https://api.github.com/users/scottferg/followers
# 379      https://api.github.com/users/jebeck/followers
#
#                                          following_url  \
# 0    https://api.github.com/users/cassidoo/followin...
# 1    https://api.github.com/users/felangel/followin...
# 2    https://api.github.com/users/dabeaz/following{...
# 3    https://api.github.com/users/sstephenson/follo...
# 4    https://api.github.com/users/mattgodbolt/follo...
# ..                                                 ...
# 375  https://api.github.com/users/cwarden/following...
# 376  https://api.github.com/users/nadrane/following...
# 377  https://api.github.com/users/rogeruiz/followin...
# 378  https://api.github.com/users/scottferg/followi...
# 379  https://api.github.com/users/jebeck/following{...
#
#                                              gists_url  ...  \
# 0    https://api.github.com/users/cassidoo/gists{/g...  ...
# 1    https://api.github.com/users/felangel/gists{/g...  ...
# 2    https://api.github.com/users/dabeaz/gists{/gis...  ...
# 3    https://api.github.com/users/sstephenson/gists...  ...
# 4    https://api.github.com/users/mattgodbolt/gists...  ...
# ..                                                 ...  ...
# 375  https://api.github.com/users/cwarden/gists{/gi...  ...
# 376  https://api.github.com/users/nadrane/gists{/gi...  ...
# 377  https://api.github.com/users/rogeruiz/gists{/g...  ...
# 378  https://api.github.com/users/scottferg/gists{/...  ...
# 379  https://api.github.com/users/jebeck/gists{/gis...  ...
#
#                        email hireable  \
# 0                        NaN      NaN
# 1       felangelov@gmail.com      NaN
# 2            dave@dabeaz.com      NaN
# 3               sam@sls.name      NaN
# 4           matt@godbolt.org      NaN
# ..                       ...      ...
# 375        cwarden@xerus.org     True
# 376  nicholasDrane@gmail.com     True
# 377                hi@rog.gr     True
# 378                      NaN      NaN
# 379                      NaN      NaN
#
#                                                    bio twitter_username  \
# 0              Making memes and dreams... and software         cassidoo
# 1    software engineer by day, software engineer by...       felangelov
# 2    Author of the Python Essential Reference (Addi...              NaN
# 3                                                  NaN              NaN
# 4    Compiler Explorer and jsbeeb creator, ex-Googl...              NaN
# ..                                                 ...              ...
# 375  Salesforce Development Professional/Linux Afic...              NaN
# 376                                                NaN              NaN
# 377  🎶 soy un in-ge-niero. I'm a computer, baby. so...         rogeruiz
# 378                                                NaN              NaN
# 379                              Dataviz eng @netflix.              NaN
#
#     public_repos public_gists followers following                 created_at  \
# 0            165           47     13380       102  2012-02-20 16:36:23+00:00
# 1            125          293      8672        67  2014-09-22 02:35:58+00:00
# 2             34           10      5180         0  2010-08-01 15:22:48+00:00
# 3             24           58      3761         0  2008-03-08 22:17:24+00:00
# 4             84           17      3397        97  2011-02-23 13:46:48+00:00
# ..           ...          ...       ...       ...                        ...
# 375          261           68       100       129  2010-09-03 22:16:37+00:00
# 376           64            3       100         1  2012-04-11 23:56:43+00:00
# 377          197          175       100       293  2011-04-02 22:38:41+00:00
# 378           66           40       100        46  2009-04-16 03:45:47+00:00
# 379           32           27       100         0  2012-03-29 21:17:59+00:00
#
#                     updated_at
# 0    2024-10-24 18:59:19+00:00
# 1    2024-10-28 17:01:55+00:00
# 2    2024-01-08 14:46:16+00:00
# 3    2024-09-28 16:33:20+00:00
# 4    2024-10-24 02:11:12+00:00
# ..                         ...
# 375  2024-02-04 12:55:56+00:00
# 376  2023-10-13 19:52:38+00:00
# 377  2024-10-24 13:58:43+00:00
# 378  2024-09-20 17:09:58+00:00
# 379  2024-09-17 17:28:48+00:00
#
# [380 rows x 33 columns]

# %%
import pandas as pd
import numpy as np

def clean_company_name(company):
    """
    Clean company names according to specified rules:
    1. Trim whitespace
    2. Strip leading @ symbol (only the first one)
    3. Convert to uppercase
    
    Args:
        company: Company name to clean
        
    Returns:
        str: Cleaned company name
    """
    if pd.isna(company) or company == '':
        return None
        
    # Convert to string in case it's not
    company = str(company)
    
    # Trim whitespace
    company = company.strip()
    
    # Strip leading @ symbol (only the first one)
    if company.startswith('@'):
        company = company[1:]
        
    # Convert to uppercase
    company = company.upper()
    
    return company

def process_users_data(filepath: str) -> pd.DataFrame:
    """
    Load and process GitHub users data according to specifications
    
    Args:
        filepath (str): Path to the CSV file
        
    Returns:
        pd.DataFrame: Processed DataFrame
    """
    try:
        # Read CSV file
        df = pd.read_csv(filepath)
        
        # Select and reorder specified columns
        columns = [
            'login', 'name', 'company', 'location', 'email', 'hireable',
            'bio', 'public_repos', 'followers', 'following', 'created_at'
        ]
        
        df = df.reindex(columns=columns)
        
        # Clean company names
        df['company'] = df['company'].apply(clean_company_name)
        
        # Convert created_at to datetime
        df['created_at'] = pd.to_datetime(df['created_at'])
        
        # Convert hireable to boolean
        df['hireable'] = df['hireable'].fillna(False).astype(bool)
        
        # Convert numeric columns
        numeric_cols = ['public_repos', 'followers', 'following']
        for col in numeric_cols:
            df[col] = pd.to_numeric(df[col], errors='coerce').fillna(0).astype(int)
        
        # Print summary statistics
        print("\nData Summary:")
        print(f"Total users: {len(df)}")
        print(f"Users with company info: {df['company'].notna().sum()}")
        print(f"Average followers: {df['followers'].mean():.1f}")
        print(f"Average public repos: {df['public_repos'].mean():.1f}")
        
        # Print sample of cleaned company names
        print("\nSample of cleaned company names:")
        companies = df[df['company'].notna()]['company'].head()
        for company in companies:
            print(f"  - {company}")
        
        return df
        
    except FileNotFoundError:
        print(f"Error: File not found at {filepath}")
        return None
    except Exception as e:
        print(f"Error processing file: {str(e)}")
        return None

def main():
    # File path
    filepath = '/home/neil/Desktop/github_chicago_users_20241030_120752.csv'
    
    # Process the data
    df = process_users_data(filepath)
    
    if df is not None:
        # Save processed data
        output_file = 'processed_users.csv'
        df.to_csv(output_file, index=False)
        print(f"\nProcessed data saved to {output_file}")
        
        # Display additional analysis
        print("\nTop 5 users by followers:")
        top_users = df.nlargest(5, 'followers')[['login', 'name', 'company', 'followers']]
        print(top_users)
        
        print("\nMost common companies:")
        company_counts = df['company'].value_counts().head()
        print(company_counts)
        
        print("\nUsers open to hiring:")
        hireable_users = df[df['hireable']][['login', 'name', 'company']].head()
        print(hireable_users)
        
        # Basic statistics
        print("\nBasic statistics:")
        print(df[['followers', 'following', 'public_repos']].describe())

if __name__ == "__main__":
    main()
# Out:
# Data Summary:
# Total users: 380
# Users with company info: 221
# Average followers: 387.4
# Average public repos: 96.5
#
# Sample of cleaned company names:
#   - GITHUB
#   - SHOREBIRDTECH
#   - DABEAZ, LLC
#   - AQUATIC CAPITAL MANAGEMENT
#   - GOOGLE
#
# Processed data saved to processed_users.csv
#
# Top 5 users by followers:
#          login              name                     company  followers
# 0     cassidoo  Cassidy Williams                      GITHUB      13380
# 1     felangel     Felix Angelov               SHOREBIRDTECH       8672
# 2       dabeaz     David Beazley                 DABEAZ, LLC       5180
# 3  sstephenson    Sam Stephenson                        None       3761
# 4  mattgodbolt      Matt Godbolt  AQUATIC CAPITAL MANAGEMENT       3397
#
# Most common companies:
# company
# UNIVERSITY OF CHICAGO          12
# GOOGLE                          6
# GITHUB                          5
# NORTHWESTERN UNIVERSITY         4
# ARGONNE NATIONAL LABORATORY     3
# Name: count, dtype: int64
#
# Users open to hiring:
#            login               name       company
# 6       khan4019       That JS Dude       NIELSEN
# 9   eddelbuettel  Dirk Eddelbuettel          None
# 12       neodigm    Scott C. Krause   INDEPENDENT
# 14      HFTrader    Henrique Bucher  VITORIAN LLC
# 15        JimLiu         Jim Liu 宝玉          None
#
# Basic statistics:
#           followers     following  public_repos
# count    380.000000    380.000000    380.000000
# mean     387.400000    130.889474     96.457895
# std      929.483579    717.787449    116.024680
# min      100.000000      0.000000      0.000000
# 25%      129.750000      2.750000     31.000000
# 50%      190.500000     20.500000     61.500000
# 75%      339.250000     82.000000    117.250000
# max    13380.000000  11909.000000   1200.000000
# /tmp/ipykernel_65744/2753748744.py:64: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['hireable'] = df['hireable'].fillna(False).astype(bool)

# %%
import pandas as pd
import requests
import time
from datetime import datetime
import os

def get_github_repos(username, headers):
    """Fetch repositories for a given GitHub user."""
    repos = []
    page = 1
    
    while len(repos) < 500:  # Limit to 500 repos per user
        url = f"https://api.github.com/users/{username}/repos"
        params = {
            'sort': 'pushed',
            'direction': 'desc',
            'per_page': 100,
            'page': page
        }
        
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 404:
            print(f"User {username} not found")
            break
        elif response.status_code != 200:
            print(f"Error fetching repos for {username}: {response.status_code}")
            print(f"Response: {response.text}")
            break
            
        page_repos = response.json()
        if not page_repos:  # No more repos
            break
            
        repos.extend(page_repos)
        page += 1
        
        # Respect rate limits
        if response.headers.get('X-RateLimit-Remaining') == '0':
            reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
            sleep_time = max(reset_time - time.time(), 0) + 1
            print(f"Rate limit reached. Sleeping for {sleep_time} seconds...")
            time.sleep(sleep_time)
    
    return repos[:500]  # Ensure we don't exceed 500 repos

def process_repos(repos, username):
    """Process repository data and return as list of dictionaries."""
    processed_repos = []
    
    for repo in repos:
        processed_repo = {
            'login': username,
            'full_name': repo.get('full_name', ''),
            'created_at': repo.get('created_at', ''),
            'stargazers_count': repo.get('stargazers_count', 0),
            'watchers_count': repo.get('watchers_count', 0),
            'language': repo.get('language', ''),
            'has_projects': repo.get('has_projects', False),
            'has_wiki': repo.get('has_wiki', False),
            'license_name': repo.get('license', {}).get('key', '')
        }
        processed_repos.append(processed_repo)
    
    return processed_repos

def main():
    # Direct token assignment (replace with your actual token)
    github_token = 'key'
    
    headers = {
        'Authorization': f'Bearer {github_token}',  # Changed to Bearer authentication
        'Accept': 'application/vnd.github.v3+json'
    }
    
    # Read users CSV
    users_df = pd.read_csv('/home/neil/Desktop/github_chicago_users_20241030_120752.csv')
    
    # Initialize list to store all repository data
    all_repos = []
    
    # Process each user
    total_users = len(users_df)
    for idx, user in enumerate(users_df['login'], 1):
        print(f"Processing user {idx}/{total_users}: {user}")
        
        try:
            # Fetch repos for user
            repos = get_github_repos(user, headers)
            
            # Process repos and add to main list
            processed_repos = process_repos(repos, user)
            all_repos.extend(processed_repos)
            
        except Exception as e:
            print(f"Error processing user {user}: {str(e)}")
            continue
        
        # Add small delay between users to be nice to GitHub API
        time.sleep(1)
    
    # Convert to DataFrame and save to CSV
    repos_df = pd.DataFrame(all_repos)
    repos_df.to_csv('repositories.csv', index=False)
    print(f"Saved {len(repos_df)} repositories to repositories.csv")

if __name__ == "__main__":
    main()
# Out:
# Processing user 1/380: cassidoo
# Error processing user cassidoo: 'NoneType' object has no attribute 'get'
# Processing user 2/380: felangel
# Error processing user felangel: 'NoneType' object has no attribute 'get'
# Processing user 3/380: dabeaz
# Error processing user dabeaz: 'NoneType' object has no attribute 'get'
# Processing user 4/380: sstephenson
# Error processing user sstephenson: 'NoneType' object has no attribute 'get'
# Processing user 5/380: mattgodbolt
# Error processing user mattgodbolt: 'NoneType' object has no attribute 'get'
# Processing user 6/380: logankilpatrick
# Error processing user logankilpatrick: 'NoneType' object has no attribute 'get'
# Processing user 7/380: khan4019
# Error processing user khan4019: 'NoneType' object has no attribute 'get'
# Processing user 8/380: adashofdata
# Error processing user adashofdata: 'NoneType' object has no attribute 'get'
# Processing user 9/380: djspiewak
# Error processing user djspiewak: 'NoneType' object has no attribute 'get'
# Processing user 10/380: eddelbuettel
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 108
#     105     print(f"Saved {len(repos_df)} repositories to repositories.csv")
#     107 if __name__ == "__main__":
# --> 108     main()
#
# Cell In[17], line 89, in main()
#      85 print(f"Processing user {idx}/{total_users}: {user}")
#      87 try:
#      88     # Fetch repos for user
# ---> 89     repos = get_github_repos(user, headers)
#      91     # Process repos and add to main list
#      92     processed_repos = process_repos(repos, user)
#
# Cell In[17], line 21, in get_github_repos(username, headers)
#      13 url = f"https://api.github.com/users/{username}/repos"
#      14 params = {
#      15     'sort': 'pushed',
#      16     'direction': 'desc',
#      17     'per_page': 100,
#      18     'page': page
#      19 }
# ---> 21 response = requests.get(url, headers=headers, params=params)
#      23 if response.status_code == 404:
#      24     print(f"User {username} not found")
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/urllib3/connectionpool.py:715, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     712     self._prepare_proxy(conn)
#     714 # Make the request on the httplib connection object.
# --> 715 httplib_response = self._make_request(
#     716     conn,
#     717     method,
#     718     url,
#     719     timeout=timeout_obj,
#     720     body=body,
#     721     headers=headers,
#     722     chunked=chunked,
#     723 )
#     725 # If we're going to release the connection in ``finally:``, then
#     726 # the response doesn't need to know about the connection. Otherwise
#     727 # it will also try to release it and we'll have a double-release
#     728 # mess.
#     729 response_conn = conn if not release_conn else None
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/urllib3/connectionpool.py:467, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     462             httplib_response = conn.getresponse()
#     463         except BaseException as e:
#     464             # Remove the TypeError from the exception chain in
#     465             # Python 3 (including for exceptions like SystemExit).
#     466             # Otherwise it looks like a bug in the code.
# --> 467             six.raise_from(e, None)
#     468 except (SocketTimeout, BaseSSLError, SocketError) as e:
#     469     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File <string>:3, in raise_from(value, from_value)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/site-packages/urllib3/connectionpool.py:462, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     459 except TypeError:
#     460     # Python 3
#     461     try:
# --> 462         httplib_response = conn.getresponse()
#     463     except BaseException as e:
#     464         # Remove the TypeError from the exception chain in
#     465         # Python 3 (including for exceptions like SystemExit).
#     466         # Otherwise it looks like a bug in the code.
#     467         six.raise_from(e, None)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/http/client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/http/client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/http/client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniforge3/envs/rapids-24.08/lib/python3.11/ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import pandas as pd
import requests
import time
from datetime import datetime
import os
import json

def get_github_repos(username, headers):
    """Fetch repositories for a given GitHub user."""
    repos = []
    page = 1
    
    while len(repos) < 500:  # Limit to 500 repos per user
        url = f"https://api.github.com/users/{username}/repos"
        params = {
            'sort': 'pushed',
            'direction': 'desc',
            'per_page': 100,
            'page': page
        }
        
        try:
            response = requests.get(url, headers=headers, params=params)
            
            # Debug information
            print(f"\nFetching repos for {username} (page {page}):")
            print(f"URL: {response.url}")
            print(f"Status Code: {response.status_code}")
            
            # Handle rate limiting
            remaining = int(response.headers.get('X-RateLimit-Remaining', 0))
            print(f"Rate limit remaining: {remaining}")
            
            if remaining == 0:
                reset_time = int(response.headers.get('X-RateLimit-Reset', 0))
                sleep_time = max(reset_time - time.time(), 0) + 1
                print(f"Rate limit reached. Sleeping for {sleep_time} seconds...")
                time.sleep(sleep_time)
                continue
            
            if response.status_code == 404:
                print(f"User {username} not found")
                return []
            elif response.status_code != 200:
                print(f"Error fetching repos for {username}: {response.status_code}")
                print(f"Response: {response.text}")
                return []
            
            page_repos = response.json()
            
            if not page_repos:  # No more repos
                break
                
            if isinstance(page_repos, list):
                repos.extend(page_repos)
                print(f"Retrieved {len(page_repos)} repos from page {page}")
                if len(page_repos) < 100:  # Last page
                    break
            else:
                print(f"Unexpected response format for {username}")
                print(f"Response: {page_repos}")
                break
                
            page += 1
            time.sleep(1)  # Be nice to the API
            
        except requests.exceptions.RequestException as e:
            print(f"Request error for {username}: {e}")
            return []
        except json.JSONDecodeError as e:
            print(f"JSON decode error for {username}: {e}")
            return []
            
    return repos[:500]  # Ensure we don't exceed 500 repos

def process_repos(repos, username):
    """Process repository data and return as list of dictionaries."""
    processed_repos = []
    
    if not repos:
        print(f"No repositories found for {username}")
        return processed_repos
        
    for repo in repos:
        try:
            # Debug info
            if repo is None:
                print(f"Found null repo object for {username}")
                continue
                
            processed_repo = {
                'login': username,
                'full_name': repo.get('full_name', ''),
                'created_at': repo.get('created_at', ''),
                'stargazers_count': repo.get('stargazers_count', 0),
                'watchers_count': repo.get('watchers_count', 0),
                'language': repo.get('language', ''),
                'has_projects': repo.get('has_projects', False),
                'has_wiki': repo.get('has_wiki', False),
                'license_name': repo.get('license', {}).get('key', '') if repo.get('license') else ''
            }
            processed_repos.append(processed_repo)
        except Exception as e:
            print(f"Error processing repo for {username}: {str(e)}")
            print(f"Problematic repo data: {repo}")
            continue
    
    return processed_repos

def main():
    # Set up authentication headers
    github_token = 'key'  # Should use environment variable in production
    
    headers = {
        'Authorization': f'Bearer {github_token}',
        'Accept': 'application/vnd.github.v3+json'
    }
    
    # Test API connection
    test_response = requests.get('https://api.github.com/user', headers=headers)
    if test_response.status_code != 200:
        print(f"API authentication failed: {test_response.status_code}")
        print(f"Response: {test_response.text}")
        return
    
    # Read users CSV
    try:
        users_df = pd.read_csv('github_chicago_users_20241030_120752.csv')
    except Exception as e:
        print(f"Error reading users CSV: {e}")
        return
    
    # Initialize list to store all repository data
    all_repos = []
    
    # Process each user
    total_users = len(users_df)
    for idx, user in enumerate(users_df['login'], 1):
        print(f"\nProcessing user {idx}/{total_users}: {user}")
        
        try:
            # Fetch repos for user
            repos = get_github_repos(user, headers)
            
            if repos:  # Only process if we got repos back
                print(f"Found {len(repos)} repos for {user}")
                processed_repos = process_repos(repos, user)
                if processed_repos:
                    print(f"Successfully processed {len(processed_repos)} repos for {user}")
                    all_repos.extend(processed_repos)
                else:
                    print(f"No repos were processed for {user}")
            
        except Exception as e:
            print(f"Error processing user {user}: {str(e)}")
            continue
        
        time.sleep(1)  # Be nice to the API
    
    # Convert to DataFrame and save to CSV
    if all_repos:
        repos_df = pd.DataFrame(all_repos)
        repos_df.to_csv('repositories.csv', index=False)
        print(f"\nSaved {len(repos_df)} repositories to repositories.csv")
    else:
        print("\nNo repositories were processed successfully.")

if __name__ == "__main__":
    main()
# Out:
# Processing user 1/380: cassidoo
#
# Fetching repos for cassidoo (page 1):
# URL: https://api.github.com/users/cassidoo/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4928
# Retrieved 100 repos from page 1
#
# Fetching repos for cassidoo (page 2):
# URL: https://api.github.com/users/cassidoo/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4927
# Retrieved 65 repos from page 2
# Found 165 repos for cassidoo
# Successfully processed 165 repos for cassidoo
#
# Processing user 2/380: felangel
#
# Fetching repos for felangel (page 1):
# URL: https://api.github.com/users/felangel/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4926
# Retrieved 100 repos from page 1
#
# Fetching repos for felangel (page 2):
# URL: https://api.github.com/users/felangel/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4925
# Retrieved 25 repos from page 2
# Found 125 repos for felangel
# Successfully processed 125 repos for felangel
#
# Processing user 3/380: dabeaz
#
# Fetching repos for dabeaz (page 1):
# URL: https://api.github.com/users/dabeaz/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4924
# Retrieved 34 repos from page 1
# Found 34 repos for dabeaz
# Successfully processed 34 repos for dabeaz
#
# Processing user 4/380: sstephenson
#
# Fetching repos for sstephenson (page 1):
# URL: https://api.github.com/users/sstephenson/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4923
# Retrieved 24 repos from page 1
# Found 24 repos for sstephenson
# Successfully processed 24 repos for sstephenson
#
# Processing user 5/380: mattgodbolt
#
# Fetching repos for mattgodbolt (page 1):
# URL: https://api.github.com/users/mattgodbolt/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4922
# Retrieved 84 repos from page 1
# Found 84 repos for mattgodbolt
# Successfully processed 84 repos for mattgodbolt
#
# Processing user 6/380: logankilpatrick
#
# Fetching repos for logankilpatrick (page 1):
# URL: https://api.github.com/users/logankilpatrick/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4921
# Retrieved 100 repos from page 1
#
# Fetching repos for logankilpatrick (page 2):
# URL: https://api.github.com/users/logankilpatrick/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4920
# Retrieved 100 repos from page 2
#
# Fetching repos for logankilpatrick (page 3):
# URL: https://api.github.com/users/logankilpatrick/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4919
# Retrieved 29 repos from page 3
# Found 229 repos for logankilpatrick
# Successfully processed 229 repos for logankilpatrick
#
# Processing user 7/380: khan4019
#
# Fetching repos for khan4019 (page 1):
# URL: https://api.github.com/users/khan4019/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4918
# Retrieved 100 repos from page 1
#
# Fetching repos for khan4019 (page 2):
# URL: https://api.github.com/users/khan4019/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4917
# Retrieved 4 repos from page 2
# Found 104 repos for khan4019
# Successfully processed 104 repos for khan4019
#
# Processing user 8/380: adashofdata
#
# Fetching repos for adashofdata (page 1):
# URL: https://api.github.com/users/adashofdata/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4916
# Retrieved 6 repos from page 1
# Found 6 repos for adashofdata
# Successfully processed 6 repos for adashofdata
#
# Processing user 9/380: djspiewak
#
# Fetching repos for djspiewak (page 1):
# URL: https://api.github.com/users/djspiewak/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4915
# Retrieved 100 repos from page 1
#
# Fetching repos for djspiewak (page 2):
# URL: https://api.github.com/users/djspiewak/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4914
# Retrieved 43 repos from page 2
# Found 143 repos for djspiewak
# Successfully processed 143 repos for djspiewak
#
# Processing user 10/380: eddelbuettel
#
# Fetching repos for eddelbuettel (page 1):
# URL: https://api.github.com/users/eddelbuettel/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4913
# Retrieved 100 repos from page 1
#
# Fetching repos for eddelbuettel (page 2):
# URL: https://api.github.com/users/eddelbuettel/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4912
# Retrieved 100 repos from page 2
#
# Fetching repos for eddelbuettel (page 3):
# URL: https://api.github.com/users/eddelbuettel/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4911
# Retrieved 100 repos from page 3
#
# Fetching repos for eddelbuettel (page 4):
# URL: https://api.github.com/users/eddelbuettel/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4910
# Retrieved 100 repos from page 4
#
# Fetching repos for eddelbuettel (page 5):
# URL: https://api.github.com/users/eddelbuettel/repos?sort=pushed&direction=desc&per_page=100&page=5
# Status Code: 200
# Rate limit remaining: 4909
# Retrieved 71 repos from page 5
# Found 471 repos for eddelbuettel
# Successfully processed 471 repos for eddelbuettel
#
# Processing user 11/380: natemoo-re
#
# Fetching repos for natemoo-re (page 1):
# URL: https://api.github.com/users/natemoo-re/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4908
# Retrieved 100 repos from page 1
#
# Fetching repos for natemoo-re (page 2):
# URL: https://api.github.com/users/natemoo-re/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4907
# Retrieved 100 repos from page 2
#
# Fetching repos for natemoo-re (page 3):
# URL: https://api.github.com/users/natemoo-re/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4906
# Retrieved 42 repos from page 3
# Found 242 repos for natemoo-re
# Successfully processed 242 repos for natemoo-re
#
# Processing user 12/380: lexi-lambda
#
# Fetching repos for lexi-lambda (page 1):
# URL: https://api.github.com/users/lexi-lambda/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4905
# Retrieved 100 repos from page 1
#
# Fetching repos for lexi-lambda (page 2):
# URL: https://api.github.com/users/lexi-lambda/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4904
# Retrieved 47 repos from page 2
# Found 147 repos for lexi-lambda
# Successfully processed 147 repos for lexi-lambda
#
# Processing user 13/380: neodigm
#
# Fetching repos for neodigm (page 1):
# URL: https://api.github.com/users/neodigm/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4903
# Retrieved 100 repos from page 1
#
# Fetching repos for neodigm (page 2):
# URL: https://api.github.com/users/neodigm/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4902
# Retrieved 100 repos from page 2
#
# Fetching repos for neodigm (page 3):
# URL: https://api.github.com/users/neodigm/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4901
# Retrieved 100 repos from page 3
#
# Fetching repos for neodigm (page 4):
# URL: https://api.github.com/users/neodigm/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4900
# Retrieved 100 repos from page 4
#
# Fetching repos for neodigm (page 5):
# URL: https://api.github.com/users/neodigm/repos?sort=pushed&direction=desc&per_page=100&page=5
# Status Code: 200
# Rate limit remaining: 4899
# Retrieved 11 repos from page 5
# Found 411 repos for neodigm
# Successfully processed 411 repos for neodigm
#
# Processing user 14/380: rentzsch
#
# Fetching repos for rentzsch (page 1):
# URL: https://api.github.com/users/rentzsch/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4898
# Retrieved 100 repos from page 1
#
# Fetching repos for rentzsch (page 2):
# URL: https://api.github.com/users/rentzsch/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4897
# Retrieved 48 repos from page 2
# Found 148 repos for rentzsch
# Successfully processed 148 repos for rentzsch
#
# Processing user 15/380: HFTrader
#
# Fetching repos for HFTrader (page 1):
# URL: https://api.github.com/users/HFTrader/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4896
# Retrieved 100 repos from page 1
#
# Fetching repos for HFTrader (page 2):
# URL: https://api.github.com/users/HFTrader/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4895
# Retrieved 13 repos from page 2
# Found 113 repos for HFTrader
# Successfully processed 113 repos for HFTrader
#
# Processing user 16/380: JimLiu
#
# Fetching repos for JimLiu (page 1):
# URL: https://api.github.com/users/JimLiu/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4894
# Retrieved 100 repos from page 1
#
# Fetching repos for JimLiu (page 2):
# URL: https://api.github.com/users/JimLiu/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4893
# Retrieved 100 repos from page 2
#
# Fetching repos for JimLiu (page 3):
# URL: https://api.github.com/users/JimLiu/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4892
# Retrieved 5 repos from page 3
# Found 205 repos for JimLiu
# Successfully processed 205 repos for JimLiu
#
# Processing user 17/380: jcs
#
# Fetching repos for jcs (page 1):
# URL: https://api.github.com/users/jcs/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4891
# Retrieved 98 repos from page 1
# Found 98 repos for jcs
# Successfully processed 98 repos for jcs
#
# Processing user 18/380: jbranchaud
#
# Fetching repos for jbranchaud (page 1):
# URL: https://api.github.com/users/jbranchaud/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4890
# Retrieved 100 repos from page 1
#
# Fetching repos for jbranchaud (page 2):
# URL: https://api.github.com/users/jbranchaud/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4889
# Retrieved 71 repos from page 2
# Found 171 repos for jbranchaud
# Successfully processed 171 repos for jbranchaud
#
# Processing user 19/380: basecamp
#
# Fetching repos for basecamp (page 1):
# URL: https://api.github.com/users/basecamp/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4888
# Retrieved 100 repos from page 1
#
# Fetching repos for basecamp (page 2):
# URL: https://api.github.com/users/basecamp/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4887
# Retrieved 92 repos from page 2
# Found 192 repos for basecamp
# Successfully processed 192 repos for basecamp
#
# Processing user 20/380: SciSharp
#
# Fetching repos for SciSharp (page 1):
# URL: https://api.github.com/users/SciSharp/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4886
# Retrieved 66 repos from page 1
# Found 66 repos for SciSharp
# Successfully processed 66 repos for SciSharp
#
# Processing user 21/380: joshdholtz
#
# Fetching repos for joshdholtz (page 1):
# URL: https://api.github.com/users/joshdholtz/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4885
# Retrieved 100 repos from page 1
#
# Fetching repos for joshdholtz (page 2):
# URL: https://api.github.com/users/joshdholtz/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4884
# Retrieved 100 repos from page 2
#
# Fetching repos for joshdholtz (page 3):
# URL: https://api.github.com/users/joshdholtz/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4883
# Retrieved 14 repos from page 3
# Found 214 repos for joshdholtz
# Successfully processed 214 repos for joshdholtz
#
# Processing user 22/380: johnpolacek
#
# Fetching repos for johnpolacek (page 1):
# URL: https://api.github.com/users/johnpolacek/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4882
# Retrieved 100 repos from page 1
#
# Fetching repos for johnpolacek (page 2):
# URL: https://api.github.com/users/johnpolacek/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4881
# Retrieved 27 repos from page 2
# Found 127 repos for johnpolacek
# Successfully processed 127 repos for johnpolacek
#
# Processing user 23/380: davidteather
#
# Fetching repos for davidteather (page 1):
# URL: https://api.github.com/users/davidteather/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4880
# Retrieved 59 repos from page 1
# Found 59 repos for davidteather
# Successfully processed 59 repos for davidteather
#
# Processing user 24/380: jeremyckahn
#
# Fetching repos for jeremyckahn (page 1):
# URL: https://api.github.com/users/jeremyckahn/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4879
# Retrieved 100 repos from page 1
#
# Fetching repos for jeremyckahn (page 2):
# URL: https://api.github.com/users/jeremyckahn/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4878
# Retrieved 55 repos from page 2
# Found 155 repos for jeremyckahn
# Successfully processed 155 repos for jeremyckahn
#
# Processing user 25/380: dchelimsky
#
# Fetching repos for dchelimsky (page 1):
# URL: https://api.github.com/users/dchelimsky/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4877
# Retrieved 100 repos from page 1
#
# Fetching repos for dchelimsky (page 2):
# URL: https://api.github.com/users/dchelimsky/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4876
# Retrieved 7 repos from page 2
# Found 107 repos for dchelimsky
# Successfully processed 107 repos for dchelimsky
#
# Processing user 26/380: coreyhaines
#
# Fetching repos for coreyhaines (page 1):
# URL: https://api.github.com/users/coreyhaines/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4875
# Retrieved 100 repos from page 1
#
# Fetching repos for coreyhaines (page 2):
# URL: https://api.github.com/users/coreyhaines/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4874
# Retrieved 55 repos from page 2
# Found 155 repos for coreyhaines
# Successfully processed 155 repos for coreyhaines
#
# Processing user 27/380: rharter
#
# Fetching repos for rharter (page 1):
# URL: https://api.github.com/users/rharter/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4873
# Retrieved 100 repos from page 1
#
# Fetching repos for rharter (page 2):
# URL: https://api.github.com/users/rharter/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4872
# Retrieved 100 repos from page 2
#
# Fetching repos for rharter (page 3):
# URL: https://api.github.com/users/rharter/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4871
# Retrieved 15 repos from page 3
# Found 215 repos for rharter
# Successfully processed 215 repos for rharter
#
# Processing user 28/380: harperreed
#
# Fetching repos for harperreed (page 1):
# URL: https://api.github.com/users/harperreed/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4870
# Retrieved 100 repos from page 1
#
# Fetching repos for harperreed (page 2):
# URL: https://api.github.com/users/harperreed/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4869
# Retrieved 81 repos from page 2
# Found 181 repos for harperreed
# Successfully processed 181 repos for harperreed
#
# Processing user 29/380: sksamuel
#
# Fetching repos for sksamuel (page 1):
# URL: https://api.github.com/users/sksamuel/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4868
# Retrieved 22 repos from page 1
# Found 22 repos for sksamuel
# Successfully processed 22 repos for sksamuel
#
# Processing user 30/380: leeoniya
#
# Fetching repos for leeoniya (page 1):
# URL: https://api.github.com/users/leeoniya/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4867
# Retrieved 100 repos from page 1
#
# Fetching repos for leeoniya (page 2):
# URL: https://api.github.com/users/leeoniya/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4866
# Retrieved 75 repos from page 2
# Found 175 repos for leeoniya
# Successfully processed 175 repos for leeoniya
#
# Processing user 31/380: hwayne
#
# Fetching repos for hwayne (page 1):
# URL: https://api.github.com/users/hwayne/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4865
# Retrieved 47 repos from page 1
# Found 47 repos for hwayne
# Successfully processed 47 repos for hwayne
#
# Processing user 32/380: CoralineAda
#
# Fetching repos for CoralineAda (page 1):
# URL: https://api.github.com/users/CoralineAda/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4864
# Retrieved 100 repos from page 1
#
# Fetching repos for CoralineAda (page 2):
# URL: https://api.github.com/users/CoralineAda/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4863
# Retrieved 36 repos from page 2
# Found 136 repos for CoralineAda
# Successfully processed 136 repos for CoralineAda
#
# Processing user 33/380: sean-codes
#
# Fetching repos for sean-codes (page 1):
# URL: https://api.github.com/users/sean-codes/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4862
# Retrieved 36 repos from page 1
# Found 36 repos for sean-codes
# Successfully processed 36 repos for sean-codes
#
# Processing user 34/380: gjreda
#
# Fetching repos for gjreda (page 1):
# URL: https://api.github.com/users/gjreda/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4861
# Retrieved 42 repos from page 1
# Found 42 repos for gjreda
# Successfully processed 42 repos for gjreda
#
# Processing user 35/380: jameslamb
#
# Fetching repos for jameslamb (page 1):
# URL: https://api.github.com/users/jameslamb/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4860
# Retrieved 88 repos from page 1
# Found 88 repos for jameslamb
# Successfully processed 88 repos for jameslamb
#
# Processing user 36/380: djsime1
#
# Fetching repos for djsime1 (page 1):
# URL: https://api.github.com/users/djsime1/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4859
# Retrieved 41 repos from page 1
# Found 41 repos for djsime1
# Successfully processed 41 repos for djsime1
#
# Processing user 37/380: dabeaz-course
#
# Fetching repos for dabeaz-course (page 1):
# URL: https://api.github.com/users/dabeaz-course/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4858
# Retrieved 2 repos from page 1
# Found 2 repos for dabeaz-course
# Successfully processed 2 repos for dabeaz-course
#
# Processing user 38/380: lorenanicole
#
# Fetching repos for lorenanicole (page 1):
# URL: https://api.github.com/users/lorenanicole/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4857
# Retrieved 100 repos from page 1
#
# Fetching repos for lorenanicole (page 2):
# URL: https://api.github.com/users/lorenanicole/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4856
# Retrieved 100 repos from page 2
#
# Fetching repos for lorenanicole (page 3):
# URL: https://api.github.com/users/lorenanicole/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4855
# Retrieved 56 repos from page 3
# Found 256 repos for lorenanicole
# Successfully processed 256 repos for lorenanicole
#
# Processing user 39/380: LadyKerr
#
# Fetching repos for LadyKerr (page 1):
# URL: https://api.github.com/users/LadyKerr/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4854
# Retrieved 100 repos from page 1
#
# Fetching repos for LadyKerr (page 2):
# URL: https://api.github.com/users/LadyKerr/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4853
# Retrieved 81 repos from page 2
# Found 181 repos for LadyKerr
# Successfully processed 181 repos for LadyKerr
#
# Processing user 40/380: dannguyen
#
# Fetching repos for dannguyen (page 1):
# URL: https://api.github.com/users/dannguyen/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4852
# Retrieved 100 repos from page 1
#
# Fetching repos for dannguyen (page 2):
# URL: https://api.github.com/users/dannguyen/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4851
# Retrieved 100 repos from page 2
#
# Fetching repos for dannguyen (page 3):
# URL: https://api.github.com/users/dannguyen/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4850
# Retrieved 100 repos from page 3
#
# Fetching repos for dannguyen (page 4):
# URL: https://api.github.com/users/dannguyen/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4849
# Retrieved 74 repos from page 4
# Found 374 repos for dannguyen
# Successfully processed 374 repos for dannguyen
#
# Processing user 41/380: awatson1978
#
# Fetching repos for awatson1978 (page 1):
# URL: https://api.github.com/users/awatson1978/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4848
# Retrieved 100 repos from page 1
#
# Fetching repos for awatson1978 (page 2):
# URL: https://api.github.com/users/awatson1978/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4847
# Retrieved 100 repos from page 2
#
# Fetching repos for awatson1978 (page 3):
# URL: https://api.github.com/users/awatson1978/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4846
# Retrieved 19 repos from page 3
# Found 219 repos for awatson1978
# Successfully processed 219 repos for awatson1978
#
# Processing user 42/380: trek
#
# Fetching repos for trek (page 1):
# URL: https://api.github.com/users/trek/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4845
# Retrieved 26 repos from page 1
# Found 26 repos for trek
# Successfully processed 26 repos for trek
#
# Processing user 43/380: Valve
#
# Fetching repos for Valve (page 1):
# URL: https://api.github.com/users/Valve/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4844
# Retrieved 61 repos from page 1
# Found 61 repos for Valve
# Successfully processed 61 repos for Valve
#
# Processing user 44/380: catarak
#
# Fetching repos for catarak (page 1):
# URL: https://api.github.com/users/catarak/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4843
# Retrieved 72 repos from page 1
# Found 72 repos for catarak
# Successfully processed 72 repos for catarak
#
# Processing user 45/380: scopatz
#
# Fetching repos for scopatz (page 1):
# URL: https://api.github.com/users/scopatz/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4842
# Retrieved 100 repos from page 1
#
# Fetching repos for scopatz (page 2):
# URL: https://api.github.com/users/scopatz/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4841
# Retrieved 100 repos from page 2
#
# Fetching repos for scopatz (page 3):
# URL: https://api.github.com/users/scopatz/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4840
# Retrieved 100 repos from page 3
#
# Fetching repos for scopatz (page 4):
# URL: https://api.github.com/users/scopatz/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4839
# Retrieved 96 repos from page 4
# Found 396 repos for scopatz
# Successfully processed 396 repos for scopatz
#
# Processing user 46/380: ZeweiChu
#
# Fetching repos for ZeweiChu (page 1):
# URL: https://api.github.com/users/ZeweiChu/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4838
# Retrieved 68 repos from page 1
# Found 68 repos for ZeweiChu
# Successfully processed 68 repos for ZeweiChu
#
# Processing user 47/380: peterpme
#
# Fetching repos for peterpme (page 1):
# URL: https://api.github.com/users/peterpme/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4837
# Retrieved 100 repos from page 1
#
# Fetching repos for peterpme (page 2):
# URL: https://api.github.com/users/peterpme/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4836
# Retrieved 100 repos from page 2
#
# Fetching repos for peterpme (page 3):
# URL: https://api.github.com/users/peterpme/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4835
# Retrieved 17 repos from page 3
# Found 217 repos for peterpme
# Successfully processed 217 repos for peterpme
#
# Processing user 48/380: bitsondatadev
#
# Fetching repos for bitsondatadev (page 1):
# URL: https://api.github.com/users/bitsondatadev/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4834
# Retrieved 46 repos from page 1
# Found 46 repos for bitsondatadev
# Successfully processed 46 repos for bitsondatadev
#
# Processing user 49/380: estrattonbailey
#
# Fetching repos for estrattonbailey (page 1):
# URL: https://api.github.com/users/estrattonbailey/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4833
# Retrieved 100 repos from page 1
#
# Fetching repos for estrattonbailey (page 2):
# URL: https://api.github.com/users/estrattonbailey/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4832
# Retrieved 79 repos from page 2
# Found 179 repos for estrattonbailey
# Successfully processed 179 repos for estrattonbailey
#
# Processing user 50/380: phinze
#
# Fetching repos for phinze (page 1):
# URL: https://api.github.com/users/phinze/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4831
# Retrieved 100 repos from page 1
#
# Fetching repos for phinze (page 2):
# URL: https://api.github.com/users/phinze/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4830
# Retrieved 55 repos from page 2
# Found 155 repos for phinze
# Successfully processed 155 repos for phinze
#
# Processing user 51/380: lvh
#
# Fetching repos for lvh (page 1):
# URL: https://api.github.com/users/lvh/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4829
# Retrieved 100 repos from page 1
#
# Fetching repos for lvh (page 2):
# URL: https://api.github.com/users/lvh/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4828
# Retrieved 88 repos from page 2
# Found 188 repos for lvh
# Successfully processed 188 repos for lvh
#
# Processing user 52/380: jorgecoca
#
# Fetching repos for jorgecoca (page 1):
# URL: https://api.github.com/users/jorgecoca/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4827
# Retrieved 9 repos from page 1
# Found 9 repos for jorgecoca
# Successfully processed 9 repos for jorgecoca
#
# Processing user 53/380: bgardner
#
# Fetching repos for bgardner (page 1):
# URL: https://api.github.com/users/bgardner/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4826
# Retrieved 2 repos from page 1
# Found 2 repos for bgardner
# Successfully processed 2 repos for bgardner
#
# Processing user 54/380: adriangb
#
# Fetching repos for adriangb (page 1):
# URL: https://api.github.com/users/adriangb/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4825
# Retrieved 100 repos from page 1
#
# Fetching repos for adriangb (page 2):
# URL: https://api.github.com/users/adriangb/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4824
# Retrieved 77 repos from page 2
# Found 177 repos for adriangb
# Successfully processed 177 repos for adriangb
#
# Processing user 55/380: Templarian
#
# Fetching repos for Templarian (page 1):
# URL: https://api.github.com/users/Templarian/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4823
# Retrieved 69 repos from page 1
# Found 69 repos for Templarian
# Successfully processed 69 repos for Templarian
#
# Processing user 56/380: jamesturk
#
# Fetching repos for jamesturk (page 1):
# URL: https://api.github.com/users/jamesturk/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4822
# Retrieved 31 repos from page 1
# Found 31 repos for jamesturk
# Successfully processed 31 repos for jamesturk
#
# Processing user 57/380: an0
#
# Fetching repos for an0 (page 1):
# URL: https://api.github.com/users/an0/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4821
# Retrieved 27 repos from page 1
# Found 27 repos for an0
# Successfully processed 27 repos for an0
#
# Processing user 58/380: kierisi
#
# Fetching repos for kierisi (page 1):
# URL: https://api.github.com/users/kierisi/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4820
# Retrieved 18 repos from page 1
# Found 18 repos for kierisi
# Successfully processed 18 repos for kierisi
#
# Processing user 59/380: derekeder
#
# Fetching repos for derekeder (page 1):
# URL: https://api.github.com/users/derekeder/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4819
# Retrieved 45 repos from page 1
# Found 45 repos for derekeder
# Successfully processed 45 repos for derekeder
#
# Processing user 60/380: rachelbaker
#
# Fetching repos for rachelbaker (page 1):
# URL: https://api.github.com/users/rachelbaker/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4818
# Retrieved 29 repos from page 1
# Found 29 repos for rachelbaker
# Successfully processed 29 repos for rachelbaker
#
# Processing user 61/380: iSoron
#
# Fetching repos for iSoron (page 1):
# URL: https://api.github.com/users/iSoron/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4817
# Retrieved 14 repos from page 1
# Found 14 repos for iSoron
# Successfully processed 14 repos for iSoron
#
# Processing user 62/380: kpdecker
#
# Fetching repos for kpdecker (page 1):
# URL: https://api.github.com/users/kpdecker/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4816
# Retrieved 100 repos from page 1
#
# Fetching repos for kpdecker (page 2):
# URL: https://api.github.com/users/kpdecker/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4815
# Retrieved 30 repos from page 2
# Found 130 repos for kpdecker
# Successfully processed 130 repos for kpdecker
#
# Processing user 63/380: themeteorchef
#
# Fetching repos for themeteorchef (page 1):
# URL: https://api.github.com/users/themeteorchef/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4814
# Retrieved 98 repos from page 1
# Found 98 repos for themeteorchef
# Successfully processed 98 repos for themeteorchef
#
# Processing user 64/380: gk5885
#
# Fetching repos for gk5885 (page 1):
# URL: https://api.github.com/users/gk5885/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4813
# Retrieved 7 repos from page 1
# Found 7 repos for gk5885
# Successfully processed 7 repos for gk5885
#
# Processing user 65/380: austinsonger
#
# Fetching repos for austinsonger (page 1):
# URL: https://api.github.com/users/austinsonger/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4812
# Retrieved 100 repos from page 1
#
# Fetching repos for austinsonger (page 2):
# URL: https://api.github.com/users/austinsonger/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4811
# Retrieved 100 repos from page 2
#
# Fetching repos for austinsonger (page 3):
# URL: https://api.github.com/users/austinsonger/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4810
# Retrieved 100 repos from page 3
#
# Fetching repos for austinsonger (page 4):
# URL: https://api.github.com/users/austinsonger/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4809
# Retrieved 100 repos from page 4
#
# Fetching repos for austinsonger (page 5):
# URL: https://api.github.com/users/austinsonger/repos?sort=pushed&direction=desc&per_page=100&page=5
# Status Code: 200
# Rate limit remaining: 4808
# Retrieved 100 repos from page 5
# Found 500 repos for austinsonger
# Successfully processed 500 repos for austinsonger
#
# Processing user 66/380: bwya77
#
# Fetching repos for bwya77 (page 1):
# URL: https://api.github.com/users/bwya77/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4807
# Retrieved 34 repos from page 1
# Found 34 repos for bwya77
# Successfully processed 34 repos for bwya77
#
# Processing user 67/380: ELLIOTTCABLE
#
# Fetching repos for ELLIOTTCABLE (page 1):
# URL: https://api.github.com/users/ELLIOTTCABLE/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4806
# Retrieved 100 repos from page 1
#
# Fetching repos for ELLIOTTCABLE (page 2):
# URL: https://api.github.com/users/ELLIOTTCABLE/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4805
# Retrieved 100 repos from page 2
#
# Fetching repos for ELLIOTTCABLE (page 3):
# URL: https://api.github.com/users/ELLIOTTCABLE/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4804
# Retrieved 43 repos from page 3
# Found 243 repos for ELLIOTTCABLE
# Successfully processed 243 repos for ELLIOTTCABLE
#
# Processing user 68/380: tqbf
#
# Fetching repos for tqbf (page 1):
# URL: https://api.github.com/users/tqbf/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4803
# Retrieved 30 repos from page 1
# Found 30 repos for tqbf
# Successfully processed 30 repos for tqbf
#
# Processing user 69/380: vehbiu
#
# Fetching repos for vehbiu (page 1):
# URL: https://api.github.com/users/vehbiu/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4802
# Retrieved 10 repos from page 1
# Found 10 repos for vehbiu
# Successfully processed 10 repos for vehbiu
#
# Processing user 70/380: mjskay
#
# Fetching repos for mjskay (page 1):
# URL: https://api.github.com/users/mjskay/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4801
# Retrieved 59 repos from page 1
# Found 59 repos for mjskay
# Successfully processed 59 repos for mjskay
#
# Processing user 71/380: mapmeld
#
# Fetching repos for mapmeld (page 1):
# URL: https://api.github.com/users/mapmeld/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4800
# Retrieved 100 repos from page 1
#
# Fetching repos for mapmeld (page 2):
# URL: https://api.github.com/users/mapmeld/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4799
# Retrieved 100 repos from page 2
#
# Fetching repos for mapmeld (page 3):
# URL: https://api.github.com/users/mapmeld/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4798
# Retrieved 74 repos from page 3
# Found 274 repos for mapmeld
# Successfully processed 274 repos for mapmeld
#
# Processing user 72/380: carolynvs
#
# Fetching repos for carolynvs (page 1):
# URL: https://api.github.com/users/carolynvs/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4797
# Retrieved 100 repos from page 1
#
# Fetching repos for carolynvs (page 2):
# URL: https://api.github.com/users/carolynvs/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4796
# Retrieved 100 repos from page 2
#
# Fetching repos for carolynvs (page 3):
# URL: https://api.github.com/users/carolynvs/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4795
# Retrieved 73 repos from page 3
# Found 273 repos for carolynvs
# Successfully processed 273 repos for carolynvs
#
# Processing user 73/380: DashBarkHuss
#
# Fetching repos for DashBarkHuss (page 1):
# URL: https://api.github.com/users/DashBarkHuss/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4794
# Retrieved 76 repos from page 1
# Found 76 repos for DashBarkHuss
# Successfully processed 76 repos for DashBarkHuss
#
# Processing user 74/380: zigurous
#
# Fetching repos for zigurous (page 1):
# URL: https://api.github.com/users/zigurous/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4793
# Retrieved 36 repos from page 1
# Found 36 repos for zigurous
# Successfully processed 36 repos for zigurous
#
# Processing user 75/380: brandonleegit
#
# Fetching repos for brandonleegit (page 1):
# URL: https://api.github.com/users/brandonleegit/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4792
# Retrieved 16 repos from page 1
# Found 16 repos for brandonleegit
# Successfully processed 16 repos for brandonleegit
#
# Processing user 76/380: rsese
#
# Fetching repos for rsese (page 1):
# URL: https://api.github.com/users/rsese/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4791
# Retrieved 44 repos from page 1
# Found 44 repos for rsese
# Successfully processed 44 repos for rsese
#
# Processing user 77/380: boonebgorges
#
# Fetching repos for boonebgorges (page 1):
# URL: https://api.github.com/users/boonebgorges/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4790
# Retrieved 100 repos from page 1
#
# Fetching repos for boonebgorges (page 2):
# URL: https://api.github.com/users/boonebgorges/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4789
# Retrieved 31 repos from page 2
# Found 131 repos for boonebgorges
# Successfully processed 131 repos for boonebgorges
#
# Processing user 78/380: jarry-xiao
#
# Fetching repos for jarry-xiao (page 1):
# URL: https://api.github.com/users/jarry-xiao/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4788
# Retrieved 23 repos from page 1
# Found 23 repos for jarry-xiao
# Successfully processed 23 repos for jarry-xiao
#
# Processing user 79/380: the-raspberry-pi-guy
#
# Fetching repos for the-raspberry-pi-guy (page 1):
# URL: https://api.github.com/users/the-raspberry-pi-guy/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4787
# Retrieved 31 repos from page 1
# Found 31 repos for the-raspberry-pi-guy
# Successfully processed 31 repos for the-raspberry-pi-guy
#
# Processing user 80/380: saforem2
#
# Fetching repos for saforem2 (page 1):
# URL: https://api.github.com/users/saforem2/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4786
# Retrieved 100 repos from page 1
#
# Fetching repos for saforem2 (page 2):
# URL: https://api.github.com/users/saforem2/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4785
# Retrieved 88 repos from page 2
# Found 188 repos for saforem2
# Successfully processed 188 repos for saforem2
#
# Processing user 81/380: ZWMiller
#
# Fetching repos for ZWMiller (page 1):
# URL: https://api.github.com/users/ZWMiller/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4784
# Retrieved 43 repos from page 1
# Found 43 repos for ZWMiller
# Successfully processed 43 repos for ZWMiller
#
# Processing user 82/380: matagus
#
# Fetching repos for matagus (page 1):
# URL: https://api.github.com/users/matagus/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4783
# Retrieved 48 repos from page 1
# Found 48 repos for matagus
# Successfully processed 48 repos for matagus
#
# Processing user 83/380: skwp
#
# Fetching repos for skwp (page 1):
# URL: https://api.github.com/users/skwp/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4782
# Retrieved 60 repos from page 1
# Found 60 repos for skwp
# Successfully processed 60 repos for skwp
#
# Processing user 84/380: stevespringett
#
# Fetching repos for stevespringett (page 1):
# URL: https://api.github.com/users/stevespringett/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4781
# Retrieved 30 repos from page 1
# Found 30 repos for stevespringett
# Successfully processed 30 repos for stevespringett
#
# Processing user 85/380: braverock
#
# Fetching repos for braverock (page 1):
# URL: https://api.github.com/users/braverock/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4780
# Retrieved 12 repos from page 1
# Found 12 repos for braverock
# Successfully processed 12 repos for braverock
#
# Processing user 86/380: jenmyers
#
# Fetching repos for jenmyers (page 1):
# URL: https://api.github.com/users/jenmyers/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4779
# Retrieved 18 repos from page 1
# Found 18 repos for jenmyers
# Successfully processed 18 repos for jenmyers
#
# Processing user 87/380: gar1t
#
# Fetching repos for gar1t (page 1):
# URL: https://api.github.com/users/gar1t/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4778
# Retrieved 100 repos from page 1
#
# Fetching repos for gar1t (page 2):
# URL: https://api.github.com/users/gar1t/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4777
# Retrieved 100 repos from page 2
#
# Fetching repos for gar1t (page 3):
# URL: https://api.github.com/users/gar1t/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4776
# Retrieved 13 repos from page 3
# Found 213 repos for gar1t
# Successfully processed 213 repos for gar1t
#
# Processing user 88/380: MarkTechson
#
# Fetching repos for MarkTechson (page 1):
# URL: https://api.github.com/users/MarkTechson/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4775
# Retrieved 97 repos from page 1
# Found 97 repos for MarkTechson
# Successfully processed 97 repos for MarkTechson
#
# Processing user 89/380: Tedko
#
# Fetching repos for Tedko (page 1):
# URL: https://api.github.com/users/Tedko/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4774
# Retrieved 56 repos from page 1
# Found 56 repos for Tedko
# Successfully processed 56 repos for Tedko
#
# Processing user 90/380: sabre1041
#
# Fetching repos for sabre1041 (page 1):
# URL: https://api.github.com/users/sabre1041/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4773
# Retrieved 100 repos from page 1
#
# Fetching repos for sabre1041 (page 2):
# URL: https://api.github.com/users/sabre1041/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4772
# Retrieved 100 repos from page 2
#
# Fetching repos for sabre1041 (page 3):
# URL: https://api.github.com/users/sabre1041/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4771
# Retrieved 100 repos from page 3
#
# Fetching repos for sabre1041 (page 4):
# URL: https://api.github.com/users/sabre1041/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4770
# Retrieved 100 repos from page 4
#
# Fetching repos for sabre1041 (page 5):
# URL: https://api.github.com/users/sabre1041/repos?sort=pushed&direction=desc&per_page=100&page=5
# Status Code: 200
# Rate limit remaining: 4769
# Retrieved 63 repos from page 5
# Found 463 repos for sabre1041
# Successfully processed 463 repos for sabre1041
#
# Processing user 91/380: loganmartintran
#
# Fetching repos for loganmartintran (page 1):
# URL: https://api.github.com/users/loganmartintran/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4768
# Retrieved 14 repos from page 1
# Found 14 repos for loganmartintran
# Successfully processed 14 repos for loganmartintran
#
# Processing user 92/380: abedra
#
# Fetching repos for abedra (page 1):
# URL: https://api.github.com/users/abedra/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4767
# Retrieved 77 repos from page 1
# Found 77 repos for abedra
# Successfully processed 77 repos for abedra
#
# Processing user 93/380: trevorturk
#
# Fetching repos for trevorturk (page 1):
# URL: https://api.github.com/users/trevorturk/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4766
# Retrieved 79 repos from page 1
# Found 79 repos for trevorturk
# Successfully processed 79 repos for trevorturk
#
# Processing user 94/380: justinbmeyer
#
# Fetching repos for justinbmeyer (page 1):
# URL: https://api.github.com/users/justinbmeyer/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4765
# Retrieved 26 repos from page 1
# Found 26 repos for justinbmeyer
# Successfully processed 26 repos for justinbmeyer
#
# Processing user 95/380: RandomFractals
#
# Fetching repos for RandomFractals (page 1):
# URL: https://api.github.com/users/RandomFractals/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4764
# Retrieved 100 repos from page 1
#
# Fetching repos for RandomFractals (page 2):
# URL: https://api.github.com/users/RandomFractals/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4763
# Retrieved 10 repos from page 2
# Found 110 repos for RandomFractals
# Successfully processed 110 repos for RandomFractals
#
# Processing user 96/380: srobbin
#
# Fetching repos for srobbin (page 1):
# URL: https://api.github.com/users/srobbin/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4762
# Retrieved 46 repos from page 1
# Found 46 repos for srobbin
# Successfully processed 46 repos for srobbin
#
# Processing user 97/380: coolbeet
#
# Fetching repos for coolbeet (page 1):
# URL: https://api.github.com/users/coolbeet/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4761
# Retrieved 8 repos from page 1
# Found 8 repos for coolbeet
# Successfully processed 8 repos for coolbeet
#
# Processing user 98/380: timrwood
#
# Fetching repos for timrwood (page 1):
# URL: https://api.github.com/users/timrwood/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4760
# Retrieved 42 repos from page 1
# Found 42 repos for timrwood
# Successfully processed 42 repos for timrwood
#
# Processing user 99/380: shayhowe
#
# Fetching repos for shayhowe (page 1):
# URL: https://api.github.com/users/shayhowe/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4759
# Retrieved 14 repos from page 1
# Found 14 repos for shayhowe
# Successfully processed 14 repos for shayhowe
#
# Processing user 100/380: ksobon
#
# Fetching repos for ksobon (page 1):
# URL: https://api.github.com/users/ksobon/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4758
# Retrieved 49 repos from page 1
# Found 49 repos for ksobon
# Successfully processed 49 repos for ksobon
#
# Processing user 101/380: hugs
#
# Fetching repos for hugs (page 1):
# URL: https://api.github.com/users/hugs/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4757
# Retrieved 74 repos from page 1
# Found 74 repos for hugs
# Successfully processed 74 repos for hugs
#
# Processing user 102/380: karllhughes
#
# Fetching repos for karllhughes (page 1):
# URL: https://api.github.com/users/karllhughes/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4756
# Retrieved 72 repos from page 1
# Found 72 repos for karllhughes
# Successfully processed 72 repos for karllhughes
#
# ...
#
# Fetching repos for rsutphin (page 1):
# URL: https://api.github.com/users/rsutphin/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4419
# Retrieved 48 repos from page 1
# Found 48 repos for rsutphin
# Successfully processed 48 repos for rsutphin
#
# Processing user 343/380: snowgy
#
# Fetching repos for snowgy (page 1):
# URL: https://api.github.com/users/snowgy/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4418
# Retrieved 30 repos from page 1
# Found 30 repos for snowgy
# Successfully processed 30 repos for snowgy
#
# Processing user 344/380: ksolo
#
# Fetching repos for ksolo (page 1):
# URL: https://api.github.com/users/ksolo/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4417
# Retrieved 100 repos from page 1
#
# Fetching repos for ksolo (page 2):
# URL: https://api.github.com/users/ksolo/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4416
# Retrieved 17 repos from page 2
# Found 117 repos for ksolo
# Successfully processed 117 repos for ksolo
#
# Processing user 345/380: SpezialK71
#
# Fetching repos for SpezialK71 (page 1):
# URL: https://api.github.com/users/SpezialK71/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4415
# Retrieved 21 repos from page 1
# Found 21 repos for SpezialK71
# Successfully processed 21 repos for SpezialK71
#
# Processing user 346/380: defaultxr
#
# Fetching repos for defaultxr (page 1):
# URL: https://api.github.com/users/defaultxr/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4414
# Retrieved 78 repos from page 1
# Found 78 repos for defaultxr
# Successfully processed 78 repos for defaultxr
#
# Processing user 347/380: stevepopovich
#
# Fetching repos for stevepopovich (page 1):
# URL: https://api.github.com/users/stevepopovich/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4413
# Retrieved 26 repos from page 1
# Found 26 repos for stevepopovich
# Successfully processed 26 repos for stevepopovich
#
# Processing user 348/380: jdoss
#
# Fetching repos for jdoss (page 1):
# URL: https://api.github.com/users/jdoss/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4412
# Retrieved 53 repos from page 1
# Found 53 repos for jdoss
# Successfully processed 53 repos for jdoss
#
# Processing user 349/380: shonumi
#
# Fetching repos for shonumi (page 1):
# URL: https://api.github.com/users/shonumi/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4411
# Retrieved 10 repos from page 1
# Found 10 repos for shonumi
# Successfully processed 10 repos for shonumi
#
# Processing user 350/380: maggiewolff
#
# Fetching repos for maggiewolff (page 1):
# URL: https://api.github.com/users/maggiewolff/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4410
# Retrieved 9 repos from page 1
# Found 9 repos for maggiewolff
# Successfully processed 9 repos for maggiewolff
#
# Processing user 351/380: andymboyle
#
# Fetching repos for andymboyle (page 1):
# URL: https://api.github.com/users/andymboyle/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4409
# Retrieved 36 repos from page 1
# Found 36 repos for andymboyle
# Successfully processed 36 repos for andymboyle
#
# Processing user 352/380: anthonyleezhang
#
# Fetching repos for anthonyleezhang (page 1):
# URL: https://api.github.com/users/anthonyleezhang/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4408
# Retrieved 7 repos from page 1
# Found 7 repos for anthonyleezhang
# Successfully processed 7 repos for anthonyleezhang
#
# Processing user 353/380: daisyUniverse
#
# Fetching repos for daisyUniverse (page 1):
# URL: https://api.github.com/users/daisyUniverse/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4407
# Retrieved 58 repos from page 1
# Found 58 repos for daisyUniverse
# Successfully processed 58 repos for daisyUniverse
#
# Processing user 354/380: maxmiller413
#
# Fetching repos for maxmiller413 (page 1):
# URL: https://api.github.com/users/maxmiller413/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4406
# Retrieved 100 repos from page 1
#
# Fetching repos for maxmiller413 (page 2):
# URL: https://api.github.com/users/maxmiller413/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4405
# Retrieved 100 repos from page 2
#
# Fetching repos for maxmiller413 (page 3):
# URL: https://api.github.com/users/maxmiller413/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4404
# Retrieved 7 repos from page 3
# Found 207 repos for maxmiller413
# Successfully processed 207 repos for maxmiller413
#
# Processing user 355/380: glitchfur
#
# Fetching repos for glitchfur (page 1):
# URL: https://api.github.com/users/glitchfur/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4403
# Retrieved 10 repos from page 1
# Found 10 repos for glitchfur
# Successfully processed 10 repos for glitchfur
#
# Processing user 356/380: wmurphyrd
#
# Fetching repos for wmurphyrd (page 1):
# URL: https://api.github.com/users/wmurphyrd/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4402
# Retrieved 63 repos from page 1
# Found 63 repos for wmurphyrd
# Successfully processed 63 repos for wmurphyrd
#
# Processing user 357/380: CodyNicholson
#
# Fetching repos for CodyNicholson (page 1):
# URL: https://api.github.com/users/CodyNicholson/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4401
# Retrieved 100 repos from page 1
#
# Fetching repos for CodyNicholson (page 2):
# URL: https://api.github.com/users/CodyNicholson/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4400
# Retrieved 58 repos from page 2
# Found 158 repos for CodyNicholson
# Successfully processed 158 repos for CodyNicholson
#
# Processing user 358/380: meltingscales
#
# Fetching repos for meltingscales (page 1):
# URL: https://api.github.com/users/meltingscales/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4399
# Retrieved 100 repos from page 1
#
# Fetching repos for meltingscales (page 2):
# URL: https://api.github.com/users/meltingscales/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4398
# Retrieved 100 repos from page 2
#
# Fetching repos for meltingscales (page 3):
# URL: https://api.github.com/users/meltingscales/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4397
# Retrieved 100 repos from page 3
#
# Fetching repos for meltingscales (page 4):
# URL: https://api.github.com/users/meltingscales/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4396
# Retrieved 36 repos from page 4
# Found 336 repos for meltingscales
# Successfully processed 336 repos for meltingscales
#
# Processing user 359/380: mgrover1
#
# Fetching repos for mgrover1 (page 1):
# URL: https://api.github.com/users/mgrover1/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4395
# Retrieved 100 repos from page 1
#
# Fetching repos for mgrover1 (page 2):
# URL: https://api.github.com/users/mgrover1/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4394
# Retrieved 98 repos from page 2
# Found 198 repos for mgrover1
# Successfully processed 198 repos for mgrover1
#
# Processing user 360/380: csantiago132
#
# Fetching repos for csantiago132 (page 1):
# URL: https://api.github.com/users/csantiago132/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4393
# Retrieved 23 repos from page 1
# Found 23 repos for csantiago132
# Successfully processed 23 repos for csantiago132
#
# Processing user 361/380: KovasMcCann
#
# Fetching repos for KovasMcCann (page 1):
# URL: https://api.github.com/users/KovasMcCann/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4392
# Retrieved 10 repos from page 1
# Found 10 repos for KovasMcCann
# Successfully processed 10 repos for KovasMcCann
#
# Processing user 362/380: jaku
#
# Fetching repos for jaku (page 1):
# URL: https://api.github.com/users/jaku/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4391
# Retrieved 49 repos from page 1
# Found 49 repos for jaku
# Successfully processed 49 repos for jaku
#
# Processing user 363/380: AbrarSyed
#
# Fetching repos for AbrarSyed (page 1):
# URL: https://api.github.com/users/AbrarSyed/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4390
# Retrieved 17 repos from page 1
# Found 17 repos for AbrarSyed
# Successfully processed 17 repos for AbrarSyed
#
# Processing user 364/380: juneau001
#
# Fetching repos for juneau001 (page 1):
# URL: https://api.github.com/users/juneau001/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4389
# Retrieved 63 repos from page 1
# Found 63 repos for juneau001
# Successfully processed 63 repos for juneau001
#
# Processing user 365/380: alycit
#
# Fetching repos for alycit (page 1):
# URL: https://api.github.com/users/alycit/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4388
# Retrieved 50 repos from page 1
# Found 50 repos for alycit
# Successfully processed 50 repos for alycit
#
# Processing user 366/380: mstratman
#
# Fetching repos for mstratman (page 1):
# URL: https://api.github.com/users/mstratman/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4387
# Retrieved 65 repos from page 1
# Found 65 repos for mstratman
# Successfully processed 65 repos for mstratman
#
# Processing user 367/380: CaryLandholt
#
# Fetching repos for CaryLandholt (page 1):
# URL: https://api.github.com/users/CaryLandholt/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4386
# Retrieved 23 repos from page 1
# Found 23 repos for CaryLandholt
# Successfully processed 23 repos for CaryLandholt
#
# Processing user 368/380: knagaitsev
#
# Fetching repos for knagaitsev (page 1):
# URL: https://api.github.com/users/knagaitsev/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4385
# Retrieved 86 repos from page 1
# Found 86 repos for knagaitsev
# Successfully processed 86 repos for knagaitsev
#
# Processing user 369/380: omargfh
#
# Fetching repos for omargfh (page 1):
# URL: https://api.github.com/users/omargfh/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4384
# Retrieved 54 repos from page 1
# Found 54 repos for omargfh
# Successfully processed 54 repos for omargfh
#
# Processing user 370/380: RonaldColyar
#
# Fetching repos for RonaldColyar (page 1):
# URL: https://api.github.com/users/RonaldColyar/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4383
# Retrieved 51 repos from page 1
# Found 51 repos for RonaldColyar
# Successfully processed 51 repos for RonaldColyar
#
# Processing user 371/380: erichilarysmithsr
#
# Fetching repos for erichilarysmithsr (page 1):
# URL: https://api.github.com/users/erichilarysmithsr/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4382
# Retrieved 100 repos from page 1
#
# Fetching repos for erichilarysmithsr (page 2):
# URL: https://api.github.com/users/erichilarysmithsr/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4381
# Retrieved 100 repos from page 2
#
# Fetching repos for erichilarysmithsr (page 3):
# URL: https://api.github.com/users/erichilarysmithsr/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4380
# Retrieved 100 repos from page 3
#
# Fetching repos for erichilarysmithsr (page 4):
# URL: https://api.github.com/users/erichilarysmithsr/repos?sort=pushed&direction=desc&per_page=100&page=4
# Status Code: 200
# Rate limit remaining: 4379
# Retrieved 100 repos from page 4
#
# Fetching repos for erichilarysmithsr (page 5):
# URL: https://api.github.com/users/erichilarysmithsr/repos?sort=pushed&direction=desc&per_page=100&page=5
# Status Code: 200
# Rate limit remaining: 4378
# Retrieved 100 repos from page 5
# Found 500 repos for erichilarysmithsr
# Successfully processed 500 repos for erichilarysmithsr
#
# Processing user 372/380: luoyuanlab
#
# Fetching repos for luoyuanlab (page 1):
# URL: https://api.github.com/users/luoyuanlab/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4377
# Retrieved 21 repos from page 1
# Found 21 repos for luoyuanlab
# Successfully processed 21 repos for luoyuanlab
#
# Processing user 373/380: jfnavarro21
#
# Fetching repos for jfnavarro21 (page 1):
# URL: https://api.github.com/users/jfnavarro21/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4376
# Retrieved 26 repos from page 1
# Found 26 repos for jfnavarro21
# Successfully processed 26 repos for jfnavarro21
#
# Processing user 374/380: rlk
#
# Fetching repos for rlk (page 1):
# URL: https://api.github.com/users/rlk/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4375
# Retrieved 33 repos from page 1
# Found 33 repos for rlk
# Successfully processed 33 repos for rlk
#
# Processing user 375/380: 3CloudSolutions
#
# Fetching repos for 3CloudSolutions (page 1):
# URL: https://api.github.com/users/3CloudSolutions/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4374
# Retrieved 6 repos from page 1
# Found 6 repos for 3CloudSolutions
# Successfully processed 6 repos for 3CloudSolutions
#
# Processing user 376/380: cwarden
#
# Fetching repos for cwarden (page 1):
# URL: https://api.github.com/users/cwarden/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4373
# Retrieved 100 repos from page 1
#
# Fetching repos for cwarden (page 2):
# URL: https://api.github.com/users/cwarden/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4372
# Retrieved 100 repos from page 2
#
# Fetching repos for cwarden (page 3):
# URL: https://api.github.com/users/cwarden/repos?sort=pushed&direction=desc&per_page=100&page=3
# Status Code: 200
# Rate limit remaining: 4371
# Retrieved 61 repos from page 3
# Found 261 repos for cwarden
# Successfully processed 261 repos for cwarden
#
# Processing user 377/380: nadrane
#
# Fetching repos for nadrane (page 1):
# URL: https://api.github.com/users/nadrane/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4370
# Retrieved 64 repos from page 1
# Found 64 repos for nadrane
# Successfully processed 64 repos for nadrane
#
# Processing user 378/380: rogeruiz
#
# Fetching repos for rogeruiz (page 1):
# URL: https://api.github.com/users/rogeruiz/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4369
# Retrieved 100 repos from page 1
#
# Fetching repos for rogeruiz (page 2):
# URL: https://api.github.com/users/rogeruiz/repos?sort=pushed&direction=desc&per_page=100&page=2
# Status Code: 200
# Rate limit remaining: 4368
# Retrieved 97 repos from page 2
# Found 197 repos for rogeruiz
# Successfully processed 197 repos for rogeruiz
#
# Processing user 379/380: scottferg
#
# Fetching repos for scottferg (page 1):
# URL: https://api.github.com/users/scottferg/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4367
# Retrieved 66 repos from page 1
# Found 66 repos for scottferg
# Successfully processed 66 repos for scottferg
#
# Processing user 380/380: jebeck
#
# Fetching repos for jebeck (page 1):
# URL: https://api.github.com/users/jebeck/repos?sort=pushed&direction=desc&per_page=100&page=1
# Status Code: 200
# Rate limit remaining: 4366
# Retrieved 32 repos from page 1
# Found 32 repos for jebeck
# Successfully processed 32 repos for jebeck
#
# Saved 35419 repositories to repositories.csv

# %%
# 1. Who are the top 5 users in Chicago with the highest number of followers? List their login in order, comma-separated.
top_users = df.nlargest(5, 'followers')['login'].tolist()
top_users
# Out:
# ['cassidoo', 'felangel', 'dabeaz', 'sstephenson', 'mattgodbolt']

# %%
#2. Who are the 5 earliest registered GitHub users in Chicago? List their login in ascending order of created_at, comma-separated.
df['created_at'] = pd.to_datetime(df['created_at'])
earliest_users = df.nsmallest(5, 'created_at')['login'].tolist()
earliest_users
# Out:
# ['ELLIOTTCABLE', 'trevorturk', 'lukehoersten', 'djspiewak', 'shanesveller']

# %%
#list all columns of df
df.columns
# Out:
# Index(['login', 'id', 'node_id', 'avatar_url', 'gravatar_id', 'url',
#        'html_url', 'followers_url', 'following_url', 'gists_url',
#        'starred_url', 'subscriptions_url', 'organizations_url', 'repos_url',
#        'events_url', 'received_events_url', 'type', 'user_view_type',
#        'site_admin', 'name', 'company', 'blog', 'location', 'email',
#        'hireable', 'bio', 'twitter_username', 'public_repos', 'public_gists',
#        'followers', 'following', 'created_at', 'updated_at'],
#       dtype='object')

# %%
# read the repositories.csv file to dt
dt = pd.read_csv('repositories.csv')

# %%
#3. What are the 3 most popular license among these users? Ignore missing licenses. List the license_name in order, comma-separated.
popular_licenses = dt['license_name'].value_counts().nlargest(3).index.tolist()
print(popular_licenses)
# Out:
# ['mit', 'other', 'apache-2.0']

# %%
#4. Which company do the majority of these developers work at?
most_common_company = df['company'].value_counts().idxmax()
print(most_common_company)
# Out:
# University of Chicago

# %%
#5. Which programming language is most popular among these users?
most_popular_language = dt['language'].value_counts().idxmax()
print(most_popular_language)
# Out:
# JavaScript

# %%
#6. Which programming language is the second most popular among users who joined after 2020?
new_users = df[df['created_at'].dt.year > 2020]
new_repos = dt[dt['login'].isin(new_users['login'])]
second_most_popular_language = new_repos['language'].value_counts().index[1]    
print(second_most_popular_language)
# Out:
# JavaScript

# %%
#7. Which language has the highest average number of stars per repository?
stars_per_repo = dt.groupby('language')['stargazers_count'].mean()
highest_avg_stars_language = stars_per_repo.idxmax()
print(highest_avg_stars_language)
# Out:
# Vim Script

# %%
#Let's define leader_strength as followers / (1 + following). Who are the top 5 in terms of leader_strength? List their login in order, comma-separated.
df['leader_strength'] = df['followers'] / (1 + df['following'])
top_leader_strength = df.nlargest(5, 'leader_strength')['login'].tolist()
top_leader_strength
# Out:
# ['dabeaz', 'sstephenson', 'khan4019', 'adashofdata', 'djspiewak']

# %%
#9. What is the correlation between the number of followers and the number of public repositories among users in Chicago? Correlation between followers and repos (to 3 decimal places, e.g. 0.123 or -0.123)
correlation = df['followers'].corr(df['public_repos'])
correlation
# Out:
# 0.07508240565044703

# %%
#10. Does creating more repos help users get more followers? Using regression, estimate how many additional followers a user gets per additional public repository. Regression slope of followers on repos (to 3 decimal places, e.g. 0.123 or -0.123)
from sklearn.linear_model import LinearRegression

X = df['public_repos'].values.reshape(-1, 1)
y = df['followers'].values

model = LinearRegression()
model.fit(X, y)
slope = model.coef_[0]

slope
# Out:
# 0.6014915352161939

# %%
#11. Do people typically enable projects and wikis together? What is the correlation between a repo having projects enabled and having wiki enabled? Correlation between projects and wiki enabled (to 3 decimal places, e.g. 0.123 or -0.123)
correlation_projects_wiki = dt['has_projects'].corr(dt['has_wiki'])
correlation_projects_wiki
# Out:
# 0.2870694402794212

# %%
# First, let's look at what values are actually in the hireable column
print("Unique values in 'hireable' column:")
print(df['hireable'].unique())

# Let's also see the value counts
print("\nValue counts in 'hireable' column:")
print(df['hireable'].value_counts())

# Fix: The column might contain None/NaN values, so we need to handle those
# Convert the hireable column to boolean, treating NaN as False
df['hireable_bool'] = df['hireable'].fillna(False)

# Now calculate the difference
hireable_following = df.groupby('hireable_bool')['following'].mean()
hireable_diff = hireable_following[True] - hireable_following[False]

# Format to 3 decimal places
formatted_diff = f"{hireable_diff:.3f}"
print("\nDifference in average following (hireable - not hireable):")
print(formatted_diff)
# Out:
# Unique values in 'hireable' column:
# [nan True]
#
# Value counts in 'hireable' column:
# hireable
# True    97
# Name: count, dtype: int64
#
# Difference in average following (hireable - not hireable):
# 109.770
# /tmp/ipykernel_65744/2625918072.py:11: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['hireable_bool'] = df['hireable'].fillna(False)

# %%
#13. Some developers write long bios. Does that help them get more followers? What's the impact of the length of their bio (in Unicode words, split by whitespace) with followers? (Ignore people without bios) Regression slope of followers on bio word count (to 3 decimal places, e.g. 12.345 or -12.345)
# Calculate bio word count
df['bio_word_count'] = df['bio'].str.split().str.len()

# Filter out users without a bio
bio_users = df.dropna(subset=['bio'])

# Perform linear regression
X = bio_users['bio_word_count'].values.reshape(-1, 1)
y = bio_users['followers'].values

model = LinearRegression()

model.fit(X, y)
slope_bio = model.coef_[0]

# Format to 3 decimal places
formatted_slope_bio = f"{slope_bio:.3f}"
print("\nRegression slope of followers on bio word count:")
print(formatted_slope_bio)
# Out:
# Regression slope of followers on bio word count:
# 3.094

# %%
#14. Who created the most repositories on weekends (UTC)? List the top 5 users' login in order, comma-separated Users login
# Convert created_at to datetime
dt['created_at'] = pd.to_datetime(dt['created_at'])

# Extract day of the week (0=Monday, 6=Sunday)
dt['day_of_week'] = dt['created_at'].dt.dayofweek

# Filter for weekends (5=Saturday, 6=Sunday)
weekend_repos = dt[dt['day_of_week'] >= 5]

# Count repositories by user
top_weekend_users = weekend_repos['login'].value_counts().nlargest(5).index.tolist()
top_weekend_users
# Out:
# ['marwahaha', 'eddelbuettel', 'sabre1041', 'erichilarysmithsr', 'yyolk']

# %%
#15. Do people who are hireable share their email addresses more often? [fraction of users with email when hireable=true] minus [fraction of users with email for the rest] (to 3 decimal places, e.g. 0.123 or -0.123)

# Calculate the difference in email sharing
email_hireable = df[df['hireable_bool']]['email'].notna().mean()
email_not_hireable = df[~df['hireable_bool']]['email'].notna().mean()
email_diff = email_hireable - email_not_hireable

# Format to 3 decimal places
formatted_email_diff = f"{email_diff:.3f}"
print("\nDifference in email sharing (hireable - not hireable):")
print(formatted_email_diff)
# Out:
# Difference in email sharing (hireable - not hireable):
# 0.076

# %%
#16. Let's assume that the last word in a user's name is their surname (ignore missing names, trim and split by whitespace.) What's the most common surname? (If there's a tie, list them all, comma-separated, alphabetically) Most common surname(s)
# Extract last word as surname
df['surname'] = df['name'].str.split().str[-1]

# Drop missing surnames
surname_counts = df['surname'].value_counts().dropna()

# Find most common surname(s)
most_common_surnames = surname_counts[surname_counts == surname_counts.max()].index.tolist()
most_common_surnames.sort()
most_common_surnames
# Out:
# ['Smith']
